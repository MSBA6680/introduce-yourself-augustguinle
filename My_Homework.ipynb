# %%
import time

print("CPU usuage: ")

for i in range(0, 101, 10):
    print(f"CPU is at {i}%")
    time.sleep(1)

print("Your computer is exploding...")
time.sleep(3)
print("JKKKKKK")
# Out:
# CPU usuage:
# CPU is at 0%
# CPU is at 10%
# CPU is at 20%
# CPU is at 30%
# CPU is at 40%
# CPU is at 50%
# CPU is at 60%
# CPU is at 70%
# CPU is at 80%
# CPU is at 90%
# CPU is at 100%
# Your computer is exploding...
# JKKKKKK

# %%
# My name is August. I enjoy swimming and reading books
